# %%
import pandas as pd

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_html("https://github.com/datasciencedojo/datasets/blob/master/titanic.csv")

# %%
df
# Out:
# [     Unnamed: 0  PassengerId  Survived  Pclass  \
#  0           NaN            1         0       3
#  1           NaN            2         1       1
#  2           NaN            3         1       3
#  3           NaN            4         1       1
#  4           NaN            5         0       3
#  ..          ...          ...       ...     ...
#  886         NaN          887         0       2
#  887         NaN          888         1       1
#  888         NaN          889         0       3
#  889         NaN          890         1       1
#  890         NaN          891         0       3
#
#                                                    Name     Sex   Age  SibSp  \
#  0                              Braund, Mr. Owen Harris    male  22.0      1
#  1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#  2                               Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
titanic_df = df[0]

# %%
titanic_df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           NaN            1         0       3
# 1           NaN            2         1       1
# 2           NaN            3         1       3
# 3           NaN            4         1       1
# 4           NaN            5         0       3
# ..          ...          ...       ...     ...
# 886         NaN          887         0       2
# 887         NaN          888         1       1
# 888         NaN          889         0       3
# 889         NaN          890         1       1
# 890         NaN          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
type(titanic_df)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_df.dtypes
# Out:
# Unnamed: 0     float64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_df.describe()
# Out:
#        Unnamed: 0  PassengerId    Survived      Pclass         Age  \
# count         0.0   891.000000  891.000000  891.000000  714.000000
# mean          NaN   446.000000    0.383838    2.308642   29.699118
# std           NaN   257.353842    0.486592    0.836071   14.526497
# min           NaN     1.000000    0.000000    1.000000    0.420000
# 25%           NaN   223.500000    0.000000    2.000000   20.125000
# 50%           NaN   446.000000    0.000000    3.000000   28.000000
# 75%           NaN   668.500000    1.000000    3.000000   38.000000
# max           NaN   891.000000    1.000000    3.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %%
type(titanic_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#check all the DATA TYPE of our COLOUMNS

titanic_df.dtypes
# Out:
# Unnamed: 0     float64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#get the data only where coloumn datatype is OBJECT

titanic_df.dtypes == 'object'
# Out:
# Unnamed: 0     False
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic_df.dtypes[titanic_df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic_df[titanic_df.dtypes[titanic_df.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
#by default it gives series

titanic_df['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
type(titanic_df['Ticket'])
# Out:
# pandas.core.series.Series

# %%
#convert it into DATA FRAME

titanic_df[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]

# %% [markdown]
# INDEXING

# %%
#want to see the data from 4th to 11 th 

titanic_df[['Ticket']][4:11]
# Out:
#      Ticket
# 4    373450
# 5    330877
# 6     17463
# 7    349909
# 8    347742
# 9    237736
# 10  PP 9549

# %%
titanic_df[['Ticket', 'Cabin']][4:11]

# %%
#take only evern entries

titanic_df[['Ticket', 'Cabin']][4:11:2]
# Out:
#      Ticket Cabin
# 4    373450   NaN
# 6     17463   E46
# 8    347742   NaN
# 10  PP 9549    G6

# %%
#ADDITION OF NEW COLOUM

titanic_df['New Col'] = titanic_df['Embarked']+ titanic_df['Sex']

# %%
titanic_df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           NaN            1         0       3
# 1           NaN            2         1       1
# 2           NaN            3         1       3
# 3           NaN            4         1       1
# 4           NaN            5         0       3
# ..          ...          ...       ...     ...
# 886         NaN          887         0       2
# 887         NaN          888         1       1
# 888         NaN          889         0       3
# 889         NaN          890         1       1
# 890         NaN          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
#find Categorical Data

# %%
pd.Categorical(titanic_df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(titanic_df['Survived'])
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
#find the unique numbers under Cabin

titanic_df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
pd.Categorical(titanic_df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
#find out the age >18

# %%
titanic_df[titanic_df['Age']>18]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           NaN            1         0       3
# 1           NaN            2         1       1
# 2           NaN            3         1       3
# 3           NaN            4         1       1
# 4           NaN            5         0       3
# ..          ...          ...       ...     ...
# 885         NaN          886         0       3
# 886         NaN          887         0       2
# 887         NaN          888         1       1
# 889         NaN          890         1       1
# 890         NaN          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
#people who are paying more than average 

titanic_df[titanic_df['Fare']>32.204]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 1           NaN            2         1       1
# 3           NaN            4         1       1
# 6           NaN            7         0       1
# 23          NaN           24         1       1
# 27          NaN           28         0       1
# ..          ...          ...       ...     ...
# 856         NaN          857         1       1
# 863         NaN          864         0       3
# 867         NaN          868         0       1
# 871         NaN          872         1       1
# 879         NaN          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ...

# %%
#check the names who get the free ticket

titanic_df[titanic_df['Fare'] == 0]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 179         NaN          180         0       3
# 263         NaN          264         0       1
# 271         NaN          272         1       3
# 277         NaN          278         0       2
# 302         NaN          303         0       3
# 413         NaN          414         0       2
# 466         NaN          467         0       2
# 481         NaN          482         0       2
# 597         NaN          598         0       3
# 633         NaN          634         0       1
# 674         NaN          675         0       2
# 732         NaN          733         0       2
# 806         NaN          807         0       1
# 815         NaN          816         0       1
# 822         NaN          823         0       1
#
#                                  Name   Sex   Age  SibSp  Parch  Ticket  Fare  \
# 179               Leonard, Mr. Lionel  male  36.0      0      0    LINE   0.0
# ...

# %%
#check how many are Male

titanic_df[titanic_df['Sex'] == 'male']
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           NaN            1         0       3
# 4           NaN            5         0       3
# 5           NaN            6         0       3
# 6           NaN            7         0       1
# 7           NaN            8         0       3
# ..          ...          ...       ...     ...
# 883         NaN          884         0       2
# 884         NaN          885         0       3
# 886         NaN          887         0       2
# 889         NaN          890         1       1
# 890         NaN          891         0       3
#
#                                Name   Sex   Age  SibSp  Parch  \
# 0           Braund, Mr. Owen Harris  male  22.0      1      0
# 4          Allen, Mr. William Henry  male  35.0      0      0
# 5                  Moran, Mr. James  male   NaN      0      0
# 6           McCarthy, Mr. Timothy J  male  54.0      0      0
# 7    Palsson, Master. Gosta Leonard  male   2.0      3      1
# ...

# %%
#check which Male pay more than avg

titanic_df[(titanic_df['Sex'] == 'male') & (titanic_df['Fare']>32)]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 6           NaN            7         0       1
# 23          NaN           24         1       1
# 27          NaN           28         0       1
# 34          NaN           35         0       1
# 35          NaN           36         0       1
# ..          ...          ...       ...     ...
# 827         NaN          828         1       2
# 838         NaN          839         1       3
# 846         NaN          847         0       3
# 848         NaN          849         0       2
# 867         NaN          868         0       1
#
#                                      Name   Sex   Age  SibSp  Parch  \
# 6                 McCarthy, Mr. Timothy J  male  54.0      0      0
# 23           Sloper, Mr. William Thompson  male  28.0      0      0
# 27         Fortune, Mr. Charles Alexander  male  19.0      3      2
# 34                Meyer, Mr. Edgar Joseph  male  28.0      1      0
# ...

# %%
#find out the name who paid max

# %%
titanic_df['Fare'] == max(titanic_df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
titanic_df[titanic_df['Fare'] == max(titanic_df['Fare'])]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 258         NaN          259         1       1
# 679         NaN          680         1       1
# 737         NaN          738         1       1
#
#                                    Name     Sex   Age  SibSp  Parch    Ticket  \
# 258                    Ward, Miss. Anna  female  35.0      0      0  PC 17755
# 679  Cardeza, Mr. Thomas Drake Martinez    male  36.0      0      1  PC 17755
# 737              Lesurer, Mr. Gustave J    male  35.0      0      0  PC 17755
#
#          Fare        Cabin Embarked  New Col
# 258  512.3292          NaN        C  Cfemale
# 679  512.3292  B51 B53 B55        C    Cmale
# 737  512.3292         B101        C    Cmale

# %%
titanic_df[titanic_df['Fare'] == max(titanic_df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
#select row 0 and col 1

titanic_df[0:2:][['PassengerId', 'Survived', 'Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %% [markdown]
# LOC & ILOC

# %% [markdown]
# iloc = take inbuilt indexes
#
#
# loc = take coloumn heading

# %%
titanic_df.iloc[0: 2,[1,2,3]]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %%
titanic_df.loc[0: 2, ['PassengerId', 'Survived', 'Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
