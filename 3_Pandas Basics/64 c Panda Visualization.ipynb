# %%
import pandas as pd

# %%
d = pd.Series([1,4,55,44,5])
d
# Out:
# 0     1
# 1     4
# 2    55
# 3    44
# 4     5
# dtype: int64

# %%
d.plot()
# Out:
# <AxesSubplot: >

# %%
d.plot.pie()
# Out:
# <AxesSubplot: >

# %%
df = pd.DataFrame( {'x': [1,32,43,4,3,43,22], 'y' : [33,3,322,3,23,3,2]})

# %%
df
# Out:
#     x    y
# 0   1   33
# 1  32    3
# 2  43  322
# 3   4    3
# 4   3   23
# 5  43    3
# 6  22    2

# %%
df.plot(x = 'x',y = 'y')
# Out:
# <AxesSubplot: xlabel='x'>

# %%
df.plot.scatter(x = 'x', y = 'y')
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>
