# %% [markdown]
# ### Student Peformance Dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("stud.csv")
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# ### Check missing values

# %%
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %% [markdown]
# ## Observation:
# there is no missing values

# %% [markdown]
# ### Check Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Observation:
# there is no duplicate values

# %% [markdown]
# ### Check Datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ## Observation:
# first 5 are objects
# last 3 are integer

# %% [markdown]
# ### Check the unique values of each columns

# %%
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %% [markdown]
# ### Statistics of Dataset

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ### Segregate numerical and categorical Feature

# %%
Categorical_feature = [feature for feature in df.columns if df[feature].dtype == 'O']
Numerical_feature = [feature for feature in df.columns if df[feature].dtype != 'O']

# %%
df['total_score'] = df['math_score']+df['reading_score']+df['writing_score']
df['average'] = df['total_score']/3
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %% [markdown]
# ### Explore more visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, axis = plt.subplots(1,2,figsize = (15,7))

plt.subplot(121)
sns.histplot(data = df, x = 'average', kde = True)

plt.subplot(122)
sns.histplot(data = df, x ='average', kde = True, hue = 'gender')
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %% [markdown]
# ### Insight
#
# Female Student has better average marks

# %%
plt.subplots(1,3, figsize = (25, 6))
plt.subplot(131)
sns.histplot(data = df, x = 'average', kde = True, hue = 'lunch')

plt.subplot(132)
sns.histplot(data = df[df['gender']=='female'], x = 'average', kde = True, hue = 'lunch')

plt.subplot(133)
sns.histplot(data = df[df['gender']=='male'], x = 'average', kde = True, hue = 'lunch')
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %% [markdown]
# ### Conclusion
#
# Standard lunch helps students to get high score in exam for both male and female

# %%
plt.subplots(1,3, figsize = (25, 6))
plt.subplot(131)
sns.histplot(data = df, x = 'average', kde = True, hue = 'parental_level_of_education')

plt.subplot(132)
sns.histplot(data = df[df['gender']=='female'], x = 'average', kde = True, hue = 'parental_level_of_education')

plt.subplot(133)
sns.histplot(data = df[df['gender']=='male'], x = 'average', kde = True, hue = 'parental_level_of_education')
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %% [markdown]
# ### Conclusion
#
#     In General Parent Education dont help student to score high in exam
#     for Female Parent Education dont help student to score high in exam
#     for Male Parent Education help student to score high in exam for Associate and Master Degree

# %%
plt.subplots(1,3, figsize = (25, 6))
plt.subplot(131)
sns.histplot(data = df, x = 'average', kde = True, hue = 'test_preparation_course')

plt.subplot(132)
sns.histplot(data = df[df['gender']=='female'], x = 'average', kde = True, hue = 'test_preparation_course')

plt.subplot(133)
sns.histplot(data = df[df['gender']=='male'], x = 'average', kde = True, hue = 'test_preparation_course')
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# /tmp/ipykernel_282/621126171.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <AxesSubplot: >

# %%
plt.subplots(1,4, figsize = (25, 6))
plt.subplot(141)
sns.histplot(data = df, x = 'math_score', kde = True, hue = 'test_preparation_course')

plt.subplot(142)
sns.histplot(data = df, x = 'math_score', kde = True, hue = 'race_ethnicity')

plt.subplot(143)
sns.histplot(data = df, x = 'math_score', kde = True, hue = 'parental_level_of_education')

plt.subplot(144)
sns.histplot(data = df, x = 'math_score', kde = True, hue = 'lunch')
#
# Out:
# <AxesSubplot: xlabel='math_score', ylabel='Count'>
